# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('seattle-weather.csv')

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#coulmn Open converted into numpy array
training_set = df.iloc[:,2:3].values
training_set
# Out:
# array([[12.8],
#        [10.6],
#        [11.7],
#        ...,
#        [ 7.2],
#        [ 5.6],
#        [ 5.6]])

# %%
len(training_set)
# Out:
# 1461

# %%
def df_to_XY(df,window_size=10):
 X_train=[]
 y_train=[]

 for i in range(10,len(training_set)):
    X_train.append(training_set[i-10:i,0])
    y_train.append(training_set[i,0])

 X_train, y_train = np.array(X_train), np.array(y_train)
 return X_train, y_train

# %%
WINDOW = 10
X,y = df_to_XY(df,WINDOW)
print(len(X),len(y))
X_train = X[:800]
y_train = y[:800]
X_val = X[800:1000]
y_val = y[800:1000]
X_test = X[1000:]
x_test = y[1000:]
# Out:
# 1451 1451

# %%
#Reshaping(To add new dimensions)
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_val = np.reshape(X_val,(X_val.shape[0],X_val.shape[1],1))
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
#Building the RNN
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

# %%
#Addinf the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units=50, return_sequences = True, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

#Output layer
regressor.add(Dense(units=1))

# %%
#Compiling
regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
#fitting the rnn to the training set
history=regressor.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 10s 94ms/step - loss: 216.6304 - val_loss: 264.2809
# Epoch 2/100
# 25/25 [==============================] - 1s 24ms/step - loss: 99.5877 - val_loss: 170.7406
# Epoch 3/100
# 25/25 [==============================] - 1s 23ms/step - loss: 74.5476 - val_loss: 141.3615
# Epoch 4/100
# 25/25 [==============================] - 1s 22ms/step - loss: 63.8051 - val_loss: 117.2254
# Epoch 5/100
# 25/25 [==============================] - 1s 23ms/step - loss: 59.0778 - val_loss: 104.6157
# Epoch 6/100
# 25/25 [==============================] - 1s 22ms/step - loss: 55.8702 - val_loss: 94.8058
# Epoch 7/100
# 25/25 [==============================] - 1s 23ms/step - loss: 54.9938 - val_loss: 88.3414
# Epoch 8/100
# 25/25 [==============================] - 1s 23ms/step - loss: 54.7852 - val_loss: 83.4732
# Epoch 9/100
# 25/25 [==============================] - 1s 22ms/step - loss: 54.1197 - val_loss: 79.4735
# Epoch 10/100
# 25/25 [==============================] - 1s 22ms/step - loss: 54.5293 - val_loss: 78.0131
# Epoch 11/100
# 25/25 [==============================] - 1s 24ms/step - loss: 53.5283 - val_loss: 76.5217
# Epoch 12/100
# 25/25 [==============================] - 1s 23ms/step - loss: 53.6962 - val_loss: 76.4093
# Epoch 13/100
# 25/25 [==============================] - 1s 22ms/step - loss: 53.7348 - val_loss: 76.5932
# Epoch 14/100
# 25/25 [==============================] - 1s 23ms/step - loss: 53.6685 - val_loss: 77.0103
# Epoch 15/100
# 25/25 [==============================] - 1s 35ms/step - loss: 54.0007 - val_loss: 77.2483
# Epoch 16/100
# 25/25 [==============================] - 1s 35ms/step - loss: 54.7013 - val_loss: 76.1475
# Epoch 17/100
# 25/25 [==============================] - 1s 34ms/step - loss: 53.8053 - val_loss: 76.0949
# Epoch 18/100
# 25/25 [==============================] - 1s 27ms/step - loss: 53.5845 - val_loss: 75.6538
# Epoch 19/100
# 25/25 [==============================] - 1s 22ms/step - loss: 54.7967 - val_loss: 75.7920
# Epoch 20/100
# 25/25 [==============================] - 1s 23ms/step - loss: 53.5560 - val_loss: 75.4608
# Epoch 21/100
# 25/25 [==============================] - 1s 23ms/step - loss: 53.9293 - val_loss: 75.9386
# Epoch 22/100
# 25/25 [==============================] - 1s 23ms/step - loss: 54.1981 - val_loss: 77.0902
# Epoch 23/100
# 25/25 [==============================] - 1s 24ms/step - loss: 51.5915 - val_loss: 74.2505
# Epoch 24/100
# 25/25 [==============================] - 1s 22ms/step - loss: 48.4758 - val_loss: 70.9031
# Epoch 25/100
# 25/25 [==============================] - 1s 24ms/step - loss: 40.3651 - val_loss: 60.7353
100
# 25/25 [==============================] - 1s 22ms/step - loss: 9.4492 - val_loss: 9.9086
# Epoch 68/100
# 25/25 [==============================] - 1s 22ms/step - loss: 9.1997 - val_loss: 9.9980
# Epoch 69/100
# 25/25 [==============================] - 1s 22ms/step - loss: 9.3190 - val_loss: 11.0595
# Epoch 70/100
# 25/25 [==============================] - 1s 22ms/step - loss: 9.9785 - val_loss: 10.0742
# Epoch 71/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.8098 - val_loss: 10.0622
# Epoch 72/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.6022 - val_loss: 9.6926
# Epoch 73/100
# 25/25 [==============================] - 1s 22ms/step - loss: 9.6482 - val_loss: 11.3156
# Epoch 74/100
# 25/25 [==============================] - 1s 23ms/step - loss: 9.1921 - val_loss: 10.6635
# Epoch 75/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.6405 - val_loss: 10.4456
# Epoch 76/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.8916 - val_loss: 9.8474
# Epoch 77/100
# 25/25 [==============================] - 1s 34ms/step - loss: 8.5160 - val_loss: 9.6470
# Epoch 78/100
# 25/25 [==============================] - 1s 32ms/step - loss: 8.6032 - val_loss: 10.2447
# Epoch 79/100
# 25/25 [==============================] - 1s 34ms/step - loss: 8.7909 - val_loss: 9.7306
# Epoch 80/100
# 25/25 [==============================] - 1s 29ms/step - loss: 8.8180 - val_loss: 10.1163
# Epoch 81/100
# 25/25 [==============================] - 1s 24ms/step - loss: 8.7168 - val_loss: 10.0726
# Epoch 82/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.9869 - val_loss: 9.9357
# Epoch 83/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.8440 - val_loss: 9.7424
# Epoch 84/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.8715 - val_loss: 9.8868
# Epoch 85/100
# 25/25 [==============================] - 1s 24ms/step - loss: 8.2387 - val_loss: 10.1948
# Epoch 86/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.6697 - val_loss: 10.6003
# Epoch 87/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.3066 - val_loss: 9.4875
# Epoch 88/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.8003 - val_loss: 9.6633
# Epoch 89/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.8490 - val_loss: 9.4602
# Epoch 90/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.4149 - val_loss: 9.5902
# Epoch 91/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.1120 - val_loss: 9.3915
# Epoch 92/100
# 25/25 [==============================] - 1s 24ms/step - loss: 8.6953 - val_loss: 9.6513
# Epoch 93/100
# 25/25 [==============================] - 1s 23ms/step - loss: 9.0212 - val_loss: 9.4152
# Epoch 94/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.2627 - val_loss: 9.5152
# Epoch 95/100
# 25/25 [==============================] - 1s 22ms/step - loss: 8.3420 - val_loss: 9.2681
# Epoch 96/100
# 25/25 [==============================] - 1s 23ms/step - loss: 8.1674 - val_loss: 9.4348
# Epoch 97/100
# 25/25 [==============================] - 1s 30ms/step - loss: 8.6792 - val_loss: 9.6703
# Epoch 98/100
# 25/25 [==============================] - 1s 37ms/step - loss: 8.7068 - val_loss: 9.8970
# Epoch 99/100
# 25/25 [==============================] - 1s 35ms/step - loss: 8.2283 - val_loss: 9.5229
# Epoch 100/100
# 25/25 [==============================] - 1s 30ms/step - loss: 8.0982 - val_loss: 9.6010

# %%
his = pd.DataFrame(history.history)

# %%
his.head()
# Out:
#          loss    val_loss
# 0  216.630356  264.280945
# 1   99.587738  170.740570
# 2   74.547554  141.361481
# 3   63.805092  117.225388
# 4   59.077763  104.615685

# %%
import seaborn as sns
his.columns
history_loss = his[['loss', 'val_loss']]


fig,axes = plt.subplots(2,1,figsize=(14,8))
plt.subplot(2,1,1)
plt.title("Loss & Val Loss")
sns.lineplot(history_loss,palette="flare");

# %%
train_pred = regressor.predict(X_train).flatten()
val_pred = regressor.predict(X_val).flatten()
test_pred = regressor.predict(X_test).flatten()
# Out:
# 25/25 [==============================] - 2s 8ms/step
# 7/7 [==============================] - 3s 10ms/step
# 15/15 [==============================] - 0s 12ms/step

# %%
pred = np.concatenate([train_pred,val_pred,test_pred])
df_pred = pd.DataFrame(df["temp_max"].copy())
df_pred.columns=["actual"]
df_pred = df_pred[WINDOW:]
df_pred["predicted"] = pred

fig,axes = plt.subplots(2,1,figsize=(14,8),dpi=400)

plt.subplot(2,1,1)
plt.title("Validation Results")
sns.lineplot(df_pred[800:],alpha=0.8,palette="flare",linestyle=None);

plt.subplot(2,1,2)
plt.title("Test Results")
sns.lineplot(df_pred[1000:],alpha=0.8,palette="flare",linestyle=None);

# %%
# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(((df_pred['predicted'] - df_pred['actual']) ** 2)))
rmse
# Out:
# 2.7116411627823025
