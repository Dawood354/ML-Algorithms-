# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %% [markdown]
# # **<span style="color:#6daa9f;">LOADING DATA</span>**

# %%
#loading data
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA PREPROCESSING</span>**
#
# **Steps involved in Data Preprocessing**
# * Dropping the outliers based on data analysis
# * Assigning values to features as X and target as y
# * Perform the scaling of the features
# * Split test and training sets

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 3s 104ms/step - loss: 0.6928 - accuracy: 0.6257 - val_loss: 0.6921 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6919 - accuracy: 0.6480 - val_loss: 0.6912 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6911 - accuracy: 0.6480 - val_loss: 0.6902 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6902 - accuracy: 0.6480 - val_loss: 0.6893 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6894 - accuracy: 0.6480 - val_loss: 0.6883 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6887 - accuracy: 0.6480 - val_loss: 0.6873 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6875 - accuracy: 0.6480 - val_loss: 0.6862 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6867 - accuracy: 0.6480 - val_loss: 0.6850 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6849 - accuracy: 0.6480 - val_loss: 0.6836 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6844 - accuracy: 0.6480 - val_loss: 0.6820 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6828 - accuracy: 0.6480 - val_loss: 0.6801 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6806 - accuracy: 0.6480 - val_loss: 0.6779 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6785 - accuracy: 0.6480 - val_loss: 0.6751 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6752 - accuracy: 0.6480 - val_loss: 0.6716 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6702 - accuracy: 0.6480 - val_loss: 0.6672 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6654 - accuracy: 0.6480 - val_loss: 0.6613 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6632 - accuracy: 0.6480 - val_loss: 0.6541 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 29ms/step - loss: 0.6572 - accuracy: 0.6480 - val_loss: 0.6456 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6477 - accuracy: 0.6480 - val_loss: 0.6357 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6344 - accuracy: 0.6480 - val_loss: 0.6239 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6228 - accuracy: 0.6480 - val_loss: 0.6099 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6138 - accuracy: 0.6480 - val_loss: 0.5945 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5945 - accuracy: 0.6480 - val_loss: 0.5778 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5823 - accuracy: 0.6480 - val_loss: 0.5618 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5810 - accuracy: 0.6480 - val_loss: 0.5470 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5532 - accuracy: 0.6480 - val_loss: 0.5338 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5445 - accuracy: 0.6480 - val_loss: 0.5235 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5374 - accuracy: 0.6480 - val_loss: 0.5150 - val_accuracy: 0.6667
# Epoch 29/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5340 - accuracy: 0.6480 - val_loss: 0.5092 - val_accuracy: 0.6667
# Epoch 30/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5583 - accuracy: 0.6480 - val_loss: 0.5069 - val_accuracy: 0.6667
# Epoch 31/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5077 - accuracy: 0.6480 - val_loss: 0.5053 - val_accuracy: 0.6667
# Epoch 32/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5192 - accuracy: 0.6480 - val_loss: 0.5034 - val_accuracy: 0.6667
# Epoch 33/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5232 - accuracy: 0.6480 - val_loss: 0.5017 - val_accuracy: 0.6667
# Epoch 34/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5317 - accuracy: 0.6480 - val_loss: 0.5012 - val_accuracy: 0.6667
# Epoch 35/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5178 - accuracy: 0.6480 - val_loss: 0.5026 - val_accuracy: 0.6667
# Epoch 36/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5197 - accuracy: 0.6480 - val_loss: 0.5032 - val_accuracy: 0.6667
# Epoch 37/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4946 - accuracy: 0.6480 - val_loss: 0.5032 - val_accuracy: 0.6667
# Epoch 38/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5429 - accuracy: 0.6480 - val_loss: 0.5030 - val_accuracy: 0.6667
# Epoch 39/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5200 - accuracy: 0.6480 - val_loss: 0.5024 - val_accuracy: 0.6667
# Epoch 40/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5116 - accuracy: 0.6480 - val_loss: 0.5025 - val_accuracy: 0.6667
# Epoch 41/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5370 - accuracy: 0.6480 - val_loss: 0.5024 - val_accuracy: 0.6667
# Epoch 42/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4872 - accuracy: 0.6480 - val_loss: 0.5039 - val_accuracy: 0.6667
# Epoch 43/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5054 - accuracy: 0.6480 - val_loss: 0.5057 - val_accuracy: 0.6667
# Epoch 44/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4973 - accuracy: 0.6480 - val_loss: 0.5062 - val_accuracy: 0.6667
# Epoch 45/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5146 - accuracy: 0.6480 - val_loss: 0.5048 - val_accuracy: 0.6667
# Epoch 46/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4946 - accuracy: 0.6480 - val_loss: 0.5058 - val_accuracy: 0.6667
# Epoch 47/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5238 - accuracy: 0.6480 - val_loss: 0.5067 - val_accuracy: 0.6667
# Epoch 48/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4636 - accuracy: 0.6480 - val_loss: 0.5070 - val_accuracy: 0.6667
# Epoch 49/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5042 - accuracy: 0.6480 - val_loss: 0.5074 - val_accuracy: 0.6667
# Epoch 50/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4938 - accuracy: 0.6480 - val_loss: 0.5093 - val_accuracy: 0.6667
# Epoch 51/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4714 - accuracy: 0.6480 - val_loss: 0.5124 - val_accuracy: 0.6667
# Epoch 52/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4916 - accuracy: 0.6480 - val_loss: 0.5144 - val_accuracy: 0.6667
# Epoch 53/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5158 - accuracy: 0.6480 - val_loss: 0.5138 - val_accuracy: 0.6667

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 66.67%

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 6ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86        57
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.76        75
#    macro avg       0.38      0.50      0.43        75
# weighted avg       0.58      0.76      0.66        75
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
